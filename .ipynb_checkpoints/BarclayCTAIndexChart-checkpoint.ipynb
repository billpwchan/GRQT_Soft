# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import sys

print(sys.version)
print(sys.path)
# Out:
# 3.7.1 (default, Dec 10 2018, 22:54:23) [MSC v.1915 64 bit (AMD64)]
# ['C:\\Users\\XPS 15\\localDocuments\\FYP', 'C:\\Anaconda3\\python37.zip', 'C:\\Anaconda3\\DLLs', 'C:\\Anaconda3\\lib', 'C:\\Anaconda3', '', 'C:\\Anaconda3\\lib\\site-packages', 'C:\\Anaconda3\\lib\\site-packages\\win32', 'C:\\Anaconda3\\lib\\site-packages\\win32\\lib', 'C:\\Anaconda3\\lib\\site-packages\\Pythonwin', 'C:\\Anaconda3\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\XPS 15\\.ipython']

# %%
file = pd.read_excel('Number-of-CTA-programs-in-index.xls', sheetname = 'Ranking Browse')
file
# Out:
#                                                                              2019  \
# NaN                                     Barclay CTA Index                     510
# Sub-Indices based on Portfolio Criteria Barclay Agricultural Traders Index     35
# NaN                                     Barclay Currency Traders Index         49
#                                         Barclay Diversified Traders Index     303
#                                         Barclay Fin./Met. Traders Index        75
# Sub-Indices based on Trading Style      Barclay Discretionary Traders Index   114
# NaN                                     Barclay Systematic Traders Index      394
#
#                                                                              2018  \
# NaN                                     Barclay CTA Index                     541
# Sub-Indices based on Portfolio Criteria Barclay Agricultural Traders Index     34
# ...

# %%
BCTA = file.iloc[0,:]
BCTA = BCTA[::-1]
type(BCTA)
# Out:
# pandas.core.series.Series

# %%
plt.figure(figsize=(20,10))
plt.plot(BCTA[-15:])
plt.title('Barclay CTA Index',fontsize=20)
plt.xlabel('years')
print('Source : https://portal.barclayhedge.com/cgi-bin/indices/displayIndices.cgi?indexID=cta')
# Out:
# Source : https://portal.barclayhedge.com/cgi-bin/indices/displayIndices.cgi?indexID=cta
